# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import warnings
import pickle
warnings.filterwarnings('ignore')

# %%
# Mount Google Drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import os
file_dir = "/content/drive/MyDrive/Colab Notebooks/DigitalSkola/Week 9/"
os.chdir(file_dir)

# %%
import pandas as pd

csv_filename = "insurance.csv"
df = pd.read_csv(csv_filename)

df.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
# !ls
# Out:
# insurance.csv  Lin_reg_model.pkl

# %% [markdown]
# !ls

# %%
#Download data here: https://drive.google.com/file/d/1_-kRegOMJmIMG6-XnDwYKnADdNounmKm/view?usp=sharing
df = pd.read_csv('insurance.csv')
df
# Out:
#       age     sex     bmi  children smoker     region      charges
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# ...   ...     ...     ...       ...    ...        ...          ...
# 1333   50    male  30.970         3     no  northwest  10600.54830
# 1334   18  female  31.920         0     no  northeast   2205.98080
# 1335   18  female  36.850         0     no  southeast   1629.83350
# 1336   21  female  25.800         0     no  southwest   2007.94500
# 1337   61  female  29.070         0    yes  northwest  29141.36030
#
# [1338 rows x 7 columns]

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
df.shape
# Out:
# (1338, 7)

# %%
df.describe()
# Out:
#                age          bmi     children       charges
# count  1338.000000  1338.000000  1338.000000   1338.000000
# mean     39.207025    30.663397     1.094918  13270.422265
# std      14.049960     6.098187     1.205493  12110.011237
# min      18.000000    15.960000     0.000000   1121.873900
# 25%      27.000000    26.296250     0.000000   4740.287150
# 50%      39.000000    30.400000     1.000000   9382.033000
# 75%      51.000000    34.693750     2.000000  16639.912515
# max      64.000000    53.130000     5.000000  63770.428010

# %%
df.dtypes
# Out:
# age           int64
# sex          object
# bmi         float64
# children      int64
# smoker       object
# region       object
# charges     float64
# dtype: object

# %%
#Objects need to be converted into categorical data

# %%
df.isnull().sum()
# Out:
# age         0
# sex         0
# bmi         0
# children    0
# smoker      0
# region      0
# charges     0
# dtype: int64

# %% [markdown]
# ### **EDA**

# %%
sns.set(style='whitegrid')
f, ax = plt.subplots(1,1, figsize=(12, 8))
ax = sns.distplot(df['charges'], kde = True, color = 'c')
plt.title('Distribution of Charges')
# Out:
# Text(0.5, 1.0, 'Distribution of Charges')

# %% [markdown]
# **Apply Natural Log**

# %% [markdown]
# Data terlalu miring (skewed) sehingga tidak mencerminkan normal distribusi. Oleh karena itu apply Natural Log untuk membuat data menjadi distribusi normal atau mencapai varian konstan.

# %%
f, ax = plt.subplots(1,1, figsize=(12, 8))
ax = sns.distplot(np.log10(df['charges']), kde = True, color = 'r')

# %% [markdown]
# **Check per Region**

# %%
#Univariate
charges = df['charges'].groupby(df.region).sum().sort_values(ascending=True)
charges_df = charges.head().reset_index().rename(columns={'region': 'Region', 'charges': 'Charges'})
f, ax = plt.subplots(1, 1, figsize=(8, 6))
ax = sns.barplot(x='Charges', y='Region', data=charges_df, palette='Blues')

# Display the plot
plt.show()

# %% [markdown]
# **Charges Per Region Based on Sex**

# %%
# Multivariate Analysis
f, ax = plt.subplots(1, 1, figsize=(12, 8))
ax = sns.barplot(x='region', y='charges', hue='sex', data=df, palette='cool')

# %% [markdown]
# **Charges per Region Based on Smoker**

# %%
f, ax = plt.subplots(1,1, figsize=(12,8))
ax = sns.barplot(x = 'region', y = 'charges',
                 hue='smoker', data=df, palette='Reds_r')

# %% [markdown]
# **Charges per Region Based on How Many Children**

# %%
f, ax = plt.subplots(1, 1, figsize=(12, 8))
ax = sns.barplot(x='region', y='charges', hue='children', data=df, palette='Set1')

# %% [markdown]
# # **Analisa Medical charges berdasarkan faktor 'Smoker' dengan prediktor lain**

# %%
ax = sns.lmplot(x = 'age', y = 'charges', data=df, hue='smoker', palette='Set1')
ax = sns.lmplot(x = 'bmi', y = 'charges', data=df, hue='smoker', palette='Set2')
ax = sns.lmplot(x = 'children', y = 'charges', data=df, hue='smoker', palette='Set3')

# %%
f, ax = plt.subplots(1, 1, figsize=(10, 10))
ax = sns.violinplot(x = 'children', y = 'charges', data=df,
                 orient='v', hue='smoker', palette='inferno')

# %% [markdown]
# # **Data Preprocessing**

# %%
#Converting objects labels into categorical
df[['sex', 'smoker', 'region']] = df[['sex', 'smoker', 'region']].astype('category')
df.dtypes
# Out:
# age            int64
# sex         category
# bmi          float64
# children       int64
# smoker      category
# region      category
# charges      float64
# dtype: object

# %%
#Converting category labels into numerical using LabelEncoder
from sklearn.preprocessing import LabelEncoder
label = LabelEncoder()
df.sex = label.fit_transform(df.sex)
df.smoker = label.fit_transform(df.smoker)
df.region = label.fit_transform(df.region)
# df.dtypes
df
# Out:
#       age  sex     bmi  children  smoker  region      charges
# 0      19    0  27.900         0       1       3  16884.92400
# 1      18    1  33.770         1       0       2   1725.55230
# 2      28    1  33.000         3       0       2   4449.46200
# 3      33    1  22.705         0       0       1  21984.47061
# 4      32    1  28.880         0       0       1   3866.85520
# ...   ...  ...     ...       ...     ...     ...          ...
# 1333   50    1  30.970         3       0       1  10600.54830
# 1334   18    0  31.920         0       0       0   2205.98080
# 1335   18    0  36.850         0       0       2   1629.83350
# 1336   21    0  25.800         0       0       3   2007.94500
# 1337   61    0  29.070         0       1       1  29141.36030
#
# [1338 rows x 7 columns]

# %%
f, ax = plt.subplots(1, 1, figsize=(10, 10))
ax = sns.heatmap(df.corr(), annot=True, cmap="cool")

# %% [markdown]
# # **Algoritma**

# %% [markdown]
# **Train Test Split**

# %%
from sklearn.model_selection import train_test_split as holdout
from sklearn.linear_model import LinearRegression
from sklearn import metrics

x = df.drop(['charges'], axis = 1) #Prediktor
y = df['charges'] #Label
x_train, x_test, y_train, y_test = holdout(x, y, test_size=0.2, random_state=0)

# %% [markdown]
# **Linear Regression**

# %%
Lin_reg = LinearRegression()
Lin_reg.fit(x_train, y_train)
y_train_pred = Lin_reg.predict(x_train)
y_test_pred = Lin_reg.predict(x_test)
print(Lin_reg.intercept_)
print(Lin_reg.coef_)
print(Lin_reg.score(x_test, y_test))
# Out:
# -11661.98390882441
# [  253.99185244   -24.32455098   328.40261701   443.72929547
#  23568.87948381  -288.50857254]
# 0.7998747145449959

# %% [markdown]
# **Lasso Regression**

# %%
from sklearn.linear_model import Lasso
Lasso = Lasso(alpha=0.2, fit_intercept=True, precompute=False, max_iter=1000,
              tol=0.0001, warm_start=False, positive=False, random_state=None, selection='cyclic')
Lasso.fit(x_train, y_train)
print(Lasso.intercept_)
print(Lasso.coef_)
print(Lasso.score(x_test, y_test))
# Out:
# -11661.83892903954
# [ 2.53991436e+02 -2.34569821e+01  3.28389438e+02  4.43587436e+02
#   2.35676136e+04 -2.88340296e+02]
# 0.7998690236224706

# %% [markdown]
# **Ridge Regression**

# %%
from sklearn.linear_model import Ridge
Ridge = Ridge(alpha=0.5)
Ridge.fit(x_train, y_train)
print(Ridge.intercept_)
print(Ridge.coef_)
print(Ridge.score(x_test, y_test))
# Out:
# -11643.440927495825
# [ 2.53893751e+02 -2.15112284e+01  3.28339566e+02  4.44238477e+02
#   2.35009674e+04 -2.89027871e+02]
# 0.7996989632063141

# %% [markdown]
# # **Evaluating Model**

# %% [markdown]
# evaluasi si linier regression

# %%
##Evaluating the performance of the algorithm
print('Mean Absolute Error:', metrics.mean_absolute_error(y_test, y_test_pred))
print('Mean Squared Error:', metrics.mean_squared_error(y_test, y_test_pred))
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(y_test, y_test_pred)))
# Out:
# Mean Absolute Error: 3930.3332739011403
# Mean Squared Error: 31845929.13415943
# Root Mean Squared Error: 5643.219748880902

# %%
##Predicting the charges
y_test_pred = Lin_reg.predict(x_test)
##Comparing the actual output values with the predicted values
df = pd.DataFrame({'Actual': y_test, 'Predicted': y_test_pred})
df
# Out:
#            Actual     Predicted
# 578    9724.53000  11017.230479
# 610    8547.69130   9787.530168
# 569   45702.02235  37994.782118
# 1034  12950.07120  16122.778407
# 198    9644.25250   6930.759230
# ...           ...           ...
# 1084  15019.76005  14699.098767
# 726    6664.68595   8210.854549
# 1132  20709.02034  16019.284542
# 725   40932.42950  33104.944084
# 963    9500.57305   9471.247528
#
# [268 rows x 2 columns]

# %% [markdown]
# # **Menyimpan Model ke Pickle**

# %%
#saving the model for the app (pilih model terbaik)
pickle.dump(Lin_reg, open( 'Lin_reg_model.pkl','wb'))

# %% [markdown]
# # **Mengintegrasi Model kedalam Flask**

# %%
# !pip install pyngrok

# %%
from flask import Flask
from flask import jsonify, request
from pyngrok import ngrok
from datetime import datetime

app = Flask(__name__)

#Loading the pickle model into flask API
with open('Lin_reg_model.pkl','rb') as file:
  model = pickle.load(file)

#First Route GET Method
@app.route('/', methods=['GET'])
def index():
  return jsonify({"Nama": "Farah Y"})

#Second Route, using model
@app.route('/predict', methods=['POST'])
def predict():
  #Get JSON data from the request (POSTMAN)
  data = request.get_json()

  #Extract feature values from JSON data
  age = data['age']
  sex = data['sex']
  bmi = data['bmi']
  children = data['children']
  smoker = data['smoker']
  region = data['region']

  #Do prediction using loaded model
  prediction = model.predict([[age, sex, bmi, children, smoker, region]])

  #Data Collection for analysis purposes
  data['Prediction'] = prediction[0]
  data['Datetime'] = datetime.now().strftime("%Y-%m-%d %H:%i:%s")

  with open("data_collection.txt","a") as file:
    file.write("%s\n" %data)

  #Return prediction result
  return jsonify({"Status": "Berhasil", "prediction": str(prediction[0])})

if __name__ == "__main__":
  #Start ngrok (server)
  ngrok_tunnel = ngrok.connect(5000)
  print("Public URL:", ngrok_tunnel.public_url)

  #Run the app
  app.run()
# Out:
# WARNING:pyngrok.process.ngrok:t=2023-07-07T10:12:28+0000 lvl=warn msg="ngrok config file found at legacy location, move to XDG location" xdg_path=/root/.config/ngrok/ngrok.yml legacy_path=/root/.ngrok2/ngrok.yml
# Public URL: https://cd53-34-83-152-118.ngrok.io
#  * Serving Flask app '__main__'
#  * Debug mode: off
# INFO:werkzeug:WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on http://127.0.0.1:5000
# INFO:werkzeug:Press CTRL+C to quit

# %%
from flask import Flask
from flask import jsonify, request
from pyngrok import ngrok

app = Flask(__name__)

#loading the pickle model into flask API
with open('Lin_reg_model.pkl','rb') as file: #rb = read binary
  model = pickle.load(file)

#first route GET method
@app.route('/', methods=['GET'])
def index():
  return jsonify({"Nama": "Aris Candra"})

#second Route, using model
@app.route('/predict', methods=['POST'])
def predict():
  #GET JSON data from the request (POSTMAN)
  data = request.get_json()

  #Extract featured values from JSON data
  age = data['age']
  sex = data['sex']
  bmi = data['bmi']
  children = data['children']
  smoker = data['smoker']
  region = data['region']

  #Do prediction using loaded model
  prediction = model.predict([[age,sex,bmi,children,smoker,region]])

  #Data collection for nalysis purpose
  data['Prediction']= prediction[0]
  data['Datetime'] = datetime.now().strftime("%Y-%m-%d %H:%i:%s")

  with open("data_collection.txt","a") as file:
    file.write("%s\n" %data)

  #return prediction result
  return jsonify({"Status": "Berhasil", "prediction": str(prediction[0])})


if __name__ == "__main__":
    #Start ngrok (server)
    ngrok_tunnel = ngrok.connect(5000) #flask itu biasanya otomatis port 5000 itu bukan sembarang angka
    print("Public URL:", ngrok_tunnel.public_url)

    #Run the app
    app.run()
# Out:
# WARNING:pyngrok.process.ngrok:t=2023-07-07T10:13:57+0000 lvl=warn msg="ngrok config file found at legacy location, move to XDG location" xdg_path=/root/.config/ngrok/ngrok.yml legacy_path=/root/.ngrok2/ngrok.yml
# Public URL: https://6c34-34-83-152-118.ngrok.io
#  * Serving Flask app '__main__'
#  * Debug mode: off
# INFO:werkzeug:WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on http://127.0.0.1:5000
# INFO:werkzeug:Press CTRL+C to quit
# INFO:werkzeug:127.0.0.1 - - [07/Jul/2023 10:14:25] "POST /predict HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [07/Jul/2023 10:14:36] "POST /predict HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [07/Jul/2023 10:15:42] "POST /predict HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [07/Jul/2023 10:24:58] "POST /predict HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [07/Jul/2023 10:31:14] "POST /predict HTTP/1.1" 200 -
# ...
